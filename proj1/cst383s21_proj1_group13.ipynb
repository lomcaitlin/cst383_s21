# %% [markdown]
# # Vehicle Collision Data Exploration
# ## Group 13: Andrew Koon and Keiti Lo
# ### CST 383: Data Science
# ### Mar 25, 2021

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import rcParams

# graphics (the right size will depend on your system)
rcParams['figure.figsize'] = 10,6
sns.set_context('notebook')   # 'talk' for slightly larger..

# %% [markdown]
# Data downloaded at ~15:21 PDT 03/16/2021 from "https://data.montgomerycountymd.gov/Public-Safety/Crash-Reporting-Drivers-Data/mmzv-x632"

# %%
# read the data
data_dir = "./crash_reporting_drivers_data.csv"
df = pd.read_csv(data_dir)
# Out:
# /Users/keitilo/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# turn the accident time into Pandas timestamp values, and make time the index
# of the dataframe
df.index = pd.to_datetime(df['Crash Date/Time'])
df = df.sort_index()

# %%
# Out:
#                     Report Number Local Case Number  \
# Crash Date/Time
# 2015-01-01 00:30:00   MCP11520005          15000008
# 2015-01-01 00:30:00   MCP11520005          15000008
# 2015-01-01 01:10:00   MCP2686000D          15000017
# 2015-01-01 01:10:00   MCP2686000D          15000017
# 2015-01-01 01:14:00   MCP2783000G          15000025
# ...                           ...               ...
# 2021-03-09 20:29:00   MCP3134002N         210008946
# 2021-03-10 07:26:00   MCP1048005F         210008977
# 2021-03-10 07:26:00   MCP1048005F         210008977
# 2021-03-10 14:35:00    DD5647000L         210009041
# 2021-03-10 14:35:00    DD5647000L         210009041
#
#                                    Agency Name       ACRS Report Type  \
# Crash Date/Time
# 2015-01-01 00:30:00   Montgomery County Police  Property Damage Crash
# 2015-01-01 00:30:00   Montgomery County Police  Property Damage Crash
# 2015-01-01 01:10:00   Montgomery County Police  Property Damage Crash
# ...
